# %%
#1) Practice
	#Dictionary
	#Tuple
	#Set

#Dictionary
d = {
    "name": "Preeti",
    "age": 20,
    "course": "BTech"

}
print(d)

print(d["name"])

#Add element
d["year"] = 2026
d["language"] = "Python"
print(d)

#Update value
d["age"] = 21

#Delete Element
del d["year"]
del d["age"]
print(d)
# Out:
# {'name': 'Preeti', 'age': 20, 'course': 'BTech'}
# Preeti
# {'name': 'Preeti', 'age': 20, 'course': 'BTech', 'year': 2026, 'language': 'Python'}
# {'name': 'Preeti', 'course': 'BTech', 'language': 'Python'}

# %%
#Tuple

t = (10,20,30,40,50)
print(t)

## Access elements
print(t[0])
print(t[2])

# Loop
for i in t:
    print(i)

print(t[1:4])
print(t[::-1])
print(len(t))
print(t.count(20))
print(t.index(30))
# Out:
# (10, 20, 30, 40, 50)
# 10
# 30
# 10
# 20
# 30
# 40
# 50
# (20, 30, 40)
# (50, 40, 30, 20, 10)
# 5
# 1
# 2

# %%
#Set

s = {"Ram", "Shyam", 'Aman'}
print(s)

s.add("Riya")          #Add Element
print(s)

s.remove("Aman")          #Add Element
print(s)

# Loop
for i in s:
    print(i)

s1 = {1,2,3}
s2 = {3,5,6}

print(s1 | s2)          #Union
print(s1 & s2)          #Intersection
print(s1 - s2)          #Difference
# Out:
# {'Ram', 'Aman', 'Shyam'}
# {'Riya', 'Ram', 'Aman', 'Shyam'}
# {'Riya', 'Ram', 'Shyam'}
# Riya
# Ram
# Shyam
# {1, 2, 3, 5, 6}
# {3}
# {1, 2}

# %%
#2) Write a function for basic math operations like add multiply substract divide and use this in your program, take 2 number input from user.

num1 = int(input("Enter First Number:"))
num2 = int(input("Enter Second Number:"))
print("First no. is:", num1)
print("Second no. is:", num2)

def add(num1, num2):
    return num1 + num2

def subtract(num1, num2):
    return num1 - num2

def multiply(num1, num2):
    return num1 * num2

def division(num1, num2):
    if num2 == 0:
        return "Division not possible"
    else:
        return num1/num2
    
print("Addition =", add(num1,num2))
print("Subtraction =", subtract(num1, num2))
print("Multiplication =", multiply(num1, num2))
print("Division =", division(num1, num2))
# Out:
# First no. is: 3
# Second no. is: 4
# Addition = 7
# Subtraction = -1
# Multiplication = 12
# Division = 0.75

# %%
#3) Write a program to check Palindrome Number For example Number 12321 is a Palindrome Number, because 12321 is equal to its reverse Number 12321.
# Steps for checking Palindrome number
#1. Find reverse of the given number.
#2. Compare that number with the reverse number.
#3. If number and its reverse is equal then it is a Palindrome Number otherwise not.


num = (input("Enter the number:"))
print("no. is:", num)
rev =  num[-1::-1]
print("Reverse of the no. is:", rev)
if num == rev :
    print("number is palindrome")
else: 
    print("number is not a palindrome")
# Out:
# no. is: 12321
# Reverse of the no. is: 12321
# number is palindrome
